# %% [markdown]
# # Preprocessing of the data

# %%
import geojson
import pandas as pd

# %% [markdown]
# ## Tree data

# %%
with open('../data/geo_data_trees.geojson') as f:
    geo_data_trees = geojson.load(f)
    
df_trees = pd.json_normalize(geo_data_trees['features'])
df_trees = df_trees.filter(regex='properties', axis=1)
df_trees.columns = df_trees.columns.str.lstrip('properties.')

df_trees.head()
# Out:
#    Tree ID                 Name DBH (cm) Replacement Value (eur)  \
# 0      1.0  Acer pseudoplatanus        8                  179.43
# 1      2.0  Acer pseudoplatanus        8                  179.43
# 2      3.0  Acer pseudoplatanus        9                  227.09
# 3      4.0  Acer pseudoplatanus       11                  482.46
# 4      7.0            Cupressus       25                 1110.29
#
#   Carbon Storage (kg) Carbon Storage (eur) Gross Carbon Sequestration (kg/yr)  \
# 0                  12                 1.92                                1.1
# 1                12.9                 2.07                                1.1
# 2                16.2                 2.61                                1.3
# 3                25.7                 4.13                                1.6
# 4               448.2                72.02                               11.1
#
#   Gross Carbon Sequestration (eur/yr) Avoided Runoff (mcube/yr)  \
# ...

# %%
df_trees.to_csv('../data_clean/trees.csv')

# %%
df_trees.set_index('Tree ID')
# Out:
#                            Name DBH (cm) Replacement Value (eur)  \
# Tree ID
# 1.0         Acer pseudoplatanus        8                  179.43
# 2.0         Acer pseudoplatanus        8                  179.43
# 3.0         Acer pseudoplatanus        9                  227.09
# 4.0         Acer pseudoplatanus       11                  482.46
# 7.0                   Cupressus       25                 1110.29
# ...                         ...      ...                     ...
# 17664.0            Philadelphus     28.2                  1354.8
# 17665.0  Forsythia x intermedia     28.2                  1354.8
# 17666.0         Aucuba japonica     28.2                  1354.8
# 17667.0      Osmanthus fragrans     28.2                  1354.8
# NaN                       Total     None                23086243
#
#         Carbon Storage (kg) Carbon Storage (eur)  \
# Tree ID
# 1.0                      12                 1.92
# 2.0                    12.9                 2.07
# ...
