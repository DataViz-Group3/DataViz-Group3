# %% [markdown]
# # Preprocessing of the data

# %%
import geopandas as gpd
import rtree
import pandas as pd

# %% [markdown]
# ## Tree data

# %%
df_trees = gpd.read_file('../data/geo_data_trees.geojson')
df_trees = df_trees.set_index('Tree ID')

df_trees.head()
# Out:
#                         Name DBH (cm) Replacement Value (eur)  \
# Tree ID
# 1.0      Acer pseudoplatanus        8                  179.43
# 2.0      Acer pseudoplatanus        8                  179.43
# 3.0      Acer pseudoplatanus        9                  227.09
# 4.0      Acer pseudoplatanus       11                  482.46
# 7.0                Cupressus       25                 1110.29
#
#         Carbon Storage (kg) Carbon Storage (eur)  \
# Tree ID
# 1.0                      12                 1.92
# 2.0                    12.9                 2.07
# 3.0                    16.2                 2.61
# 4.0                    25.7                 4.13
# 7.0                   448.2                72.02
#
#         Gross Carbon Sequestration (kg/yr)  \
# Tree ID
# 1.0                                    1.1
# 2.0                                    1.1
# 3.0                                    1.3
# 4.0                                    1.6
# 7.0                                   11.1
#
#         Gross Carbon Sequestration (eur/yr) Avoided Runoff (mcube/yr)  \
# Tree ID
# 1.0                                    0.17                         0
# 2.0                                    0.18                         0
# 3.0                                     0.2                         0
# 4.0                                    0.26                         0
# 7.0                                    1.78                         0
#
#         Avoided Runoff (eur/yr) Carbon Avoided (kg/yr)  ...  \
# Tree ID                                                 ...
# 1.0                        0.01                   None  ...
# 2.0                        0.01                   None  ...
# 3.0                        0.01                   None  ...
# 4.0                        0.02                   None  ...
# 7.0                        0.02                   None  ...
#
#         Oxygen Production (kg/yr) Height (m) Crown Height (m) Crown Width (m)  \
# Tree ID
# 1.0                           2.8        3.5                1             1.5
# 2.0                             3          5              1.5             1.5
# 3.0                           3.4        4.5              1.3             1.5
# 4.0                           4.3          5              1.5             2.5
# 7.0                          29.5          8              2.4             1.5
#
#         Canopy Cover (m2) Leaf Area (m2) Leaf Biomass (kg)   Latitude  \
# Tree ID
# 1.0                   1.8            3.5               0.2  46.051599
# 2.0                   1.8            4.2               0.3  46.051541
# 3.0                   1.8              4               0.3  46.051668
# 4.0                   4.9            7.1               0.5  46.063778
# 7.0                   1.8            6.6               1.5  46.052305
#
#          Longitude                   geometry
# Tree ID
# 1.0      11.072014  POINT (11.07201 46.05160)
# 2.0      11.072108  POINT (11.07211 46.05154)
# 3.0      11.071959  POINT (11.07196 46.05167)
# 4.0      11.150170  POINT (11.15017 46.06378)
# 7.0      11.071550  POINT (11.07155 46.05230)
#
# [5 rows x 25 columns]

# %%
df_trees.to_csv('../data_clean/trees.csv')

# %% [markdown]
# ## Circoscrizioni

# %%
df_circoscrizioni = gpd.read_file('../data/circoscrizioni.json')
df_circoscrizioni.head()
# Out:
#    numero_cir      area  perimetro                 nome  \
# 0           2  15712181      17850                MEANO
# 1           3  36949609      38485              BONDONE
# 2           4   8663138      16403             SARDAGNA
# 3           6  13199398      20575           ARGENTARIO
# 4          11   3073349      10962  S.GIUSEPPE-S.CHIARA
#
#                                       fumetto  \
# 0                 Circoscrizione n. 2 - MEANO
# 1               Circoscrizione n. 3 - BONDONE
# 2              Circoscrizione n. 4 - SARDAGNA
# 3            Circoscrizione n. 6 - ARGENTARIO
# 4  Circoscrizione n. 11 - S.GIUSEPPE-S.CHIARA
#
#                                             geometry
# 0  POLYGON ((11.15678 46.11661, 11.15687 46.11666...
# 1  POLYGON ((11.08026 46.11571, 11.08026 46.11571...
# 2  POLYGON ((11.09034 46.07917, 11.09032 46.07899...
# 3  POLYGON ((11.17163 46.08095, 11.17161 46.08106...
# 4  POLYGON ((11.11135 46.05878, 11.11137 46.05878...

# %%
df_tree_circo = gpd.tools.sjoin(df_trees, df_circoscrizioni, predicate="within", how='left')
# Out:
#                            Name DBH (cm) Replacement Value (eur)  \
# Tree ID
# 1.0         Acer pseudoplatanus        8                  179.43
# 2.0         Acer pseudoplatanus        8                  179.43
# 3.0         Acer pseudoplatanus        9                  227.09
# 4.0         Acer pseudoplatanus       11                  482.46
# 7.0                   Cupressus       25                 1110.29
# ...                         ...      ...                     ...
# 17664.0            Philadelphus     28.2                  1354.8
# 17665.0  Forsythia x intermedia     28.2                  1354.8
# 17666.0         Aucuba japonica     28.2                  1354.8
# 17667.0      Osmanthus fragrans     28.2                  1354.8
# NaN                       Total     None                23086243
#
#         Carbon Storage (kg) Carbon Storage (eur)  \
# Tree ID
# 1.0                      12                 1.92
# 2.0                    12.9                 2.07
# 3.0                    16.2                 2.61
# 4.0                    25.7                 4.13
# 7.0                   448.2                72.02
# ...                     ...                  ...
# 17664.0               396.2                63.66
# 17665.0               320.9                51.56
# 17666.0               356.2                57.22
# 17667.0               240.7                38.67
# NaN                 5484735               881216
#
#         Gross Carbon Sequestration (kg/yr)  \
# Tree ID
# 1.0                                    1.1
# 2.0                                    1.1
# 3.0                                    1.3
# 4.0                                    1.6
# 7.0                                   11.1
# ...                                    ...
# 17664.0                               10.7
# 17665.0                               10.5
# 17666.0                                6.3
# 17667.0                                4.3
# NaN                                  71714
#
#         Gross Carbon Sequestration (eur/yr) Avoided Runoff (mcube/yr)  \
# Tree ID
# 1.0                                    0.17                         0
# 2.0                                    0.18                         0
# 3.0                                     0.2                         0
# 4.0                                    0.26                         0
# 7.0                                    1.78                         0
# ...                                     ...                       ...
# 17664.0                                1.71                       0.1
# 17665.0                                1.68                       0.1
# 17666.0                                1.01                       0.1
# 17667.0                  0.6899999999999999                       0.1
# NaN                                   11522                      2270
#
#         Avoided Runoff (eur/yr) Carbon Avoided (kg/yr)  ... Leaf Biomass (kg)  \
# Tree ID                                                 ...
# 1.0                        0.01                   None  ...               0.2
# 2.0                        0.01                   None  ...               0.3
# 3.0                        0.01                   None  ...               0.3
# 4.0                        0.02                   None  ...               0.5
# 7.0                        0.02                   None  ...               1.5
# ...                         ...                    ...  ...               ...
# 17664.0                    0.13                   None  ...               2.7
# 17665.0                    0.21                   None  ...               4.6
# 17666.0                    0.14                   None  ...               2.5
# 17667.0                    0.15                   None  ...               3.8
# NaN                        4317                   None  ...          101770.6
#
#           Latitude  Longitude                   geometry index_right  \
# Tree ID
# 1.0      46.051599  11.072014  POINT (11.07201 46.05160)         2.0
# 2.0      46.051541  11.072108  POINT (11.07211 46.05154)         2.0
# 3.0      46.051668  11.071959  POINT (11.07196 46.05167)         2.0
# 4.0      46.063778  11.150170  POINT (11.15017 46.06378)         5.0
# 7.0      46.052305  11.071550  POINT (11.07155 46.05230)         2.0
# ...            ...        ...                        ...         ...
# 17664.0  46.055851  11.129388  POINT (11.12939 46.05585)         9.0
# 17665.0  46.055402  11.129206  POINT (11.12921 46.05540)         9.0
# 17666.0  46.055867  11.129650  POINT (11.12965 46.05587)         9.0
# 17667.0  46.053467  11.121152  POINT (11.12115 46.05347)         4.0
# NaN            NaN        NaN                       None         NaN
#
#         numero_cir        area perimetro                 nome  \
# Tree ID
# 1.0            4.0   8663138.0   16403.0             SARDAGNA
# 2.0            4.0   8663138.0   16403.0             SARDAGNA
# 3.0            4.0   8663138.0   16403.0             SARDAGNA
# 4.0            7.0  15433274.0   18464.0                 POVO
# 7.0            4.0   8663138.0   16403.0             SARDAGNA
# ...            ...         ...       ...                  ...
# 17664.0       10.0   6962104.0   15418.0         OLTREFERSINA
# 17665.0       10.0   6962104.0   15418.0         OLTREFERSINA
# 17666.0       10.0   6962104.0   15418.0         OLTREFERSINA
# 17667.0       11.0   3073349.0   10962.0  S.GIUSEPPE-S.CHIARA
# NaN            NaN         NaN       NaN                  NaN
#
#                                             fumetto
# Tree ID
# 1.0                  Circoscrizione n. 4 - SARDAGNA
# 2.0                  Circoscrizione n. 4 - SARDAGNA
# 3.0                  Circoscrizione n. 4 - SARDAGNA
# 4.0                      Circoscrizione n. 7 - POVO
# 7.0                  Circoscrizione n. 4 - SARDAGNA
# ...                                             ...
# 17664.0         Circoscrizione n. 10 - OLTREFERSINA
# 17665.0         Circoscrizione n. 10 - OLTREFERSINA
# 17666.0         Circoscrizione n. 10 - OLTREFERSINA
# 17667.0  Circoscrizione n. 11 - S.GIUSEPPE-S.CHIARA
# NaN                                             NaN
#
# [12513 rows x 31 columns]

# %%
gpd.read_file('../data/circoscrizioni.json')
# Out:
#     numero_cir      area  perimetro                          nome  \
# 0            2  15712181      17850                         MEANO
# 1            3  36949609      38485                       BONDONE
# 2            4   8663138      16403                      SARDAGNA
# 3            6  13199398      20575                    ARGENTARIO
# 4           11   3073349      10962           S.GIUSEPPE-S.CHIARA
# 5            7  15433274      18464                          POVO
# 6            5  16687779      27197              RAVINA-ROMAGNANO
# 7            8  16409555      24413                    MATTARELLO
# 8            9   7342864      15395                    VILLAZZANO
# 9           10   6962104      15418                  OLTREFERSINA
# 10           1   8817959      14719                       GARDOLO
# 11          12   8599464      23151  CENTRO STORICO PIEDICASTELLO
#
#                                               fumetto  \
# 0                         Circoscrizione n. 2 - MEANO
# 1                       Circoscrizione n. 3 - BONDONE
# 2                      Circoscrizione n. 4 - SARDAGNA
# 3                    Circoscrizione n. 6 - ARGENTARIO
# 4          Circoscrizione n. 11 - S.GIUSEPPE-S.CHIARA
# 5                          Circoscrizione n. 7 - POVO
# 6              Circoscrizione n. 5 - RAVINA-ROMAGNANO
# 7                    Circoscrizione n. 8 - MATTARELLO
# 8                    Circoscrizione n. 9 - VILLAZZANO
# 9                 Circoscrizione n. 10 - OLTREFERSINA
# 10                      Circoscrizione n. 1 - GARDOLO
# 11  Circoscrizione n. 12 - CENTRO STORICO PIEDICAS...
#
#                                              geometry
# 0   POLYGON ((11.15678 46.11661, 11.15687 46.11666...
# 1   POLYGON ((11.08026 46.11571, 11.08026 46.11571...
# 2   POLYGON ((11.09034 46.07917, 11.09032 46.07899...
# 3   POLYGON ((11.17163 46.08095, 11.17161 46.08106...
# 4   POLYGON ((11.11135 46.05878, 11.11137 46.05878...
# 5   POLYGON ((11.18467 46.02957, 11.18467 46.02957...
# 6   POLYGON ((11.11591 45.98873, 11.11597 45.98890...
# 7   POLYGON ((11.11591 45.98873, 11.11644 45.98845...
# 8   POLYGON ((11.15706 46.01669, 11.15723 46.01684...
# 9   POLYGON ((11.11723 46.04331, 11.11754 46.04306...
# 10  POLYGON ((11.11614 46.10914, 11.11606 46.10909...
# 11  POLYGON ((11.12826 46.07593, 11.12802 46.07610...
